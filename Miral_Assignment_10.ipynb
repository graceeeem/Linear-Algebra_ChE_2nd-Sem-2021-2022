# %% [markdown]
# <a href="https://colab.research.google.com/github/graceeeem/Linear-Algebra_ChE_2nd-Sem-2021-2022/blob/main/Miral_Assignment_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Algebra for ChE
# ## Laboratory 10 : Linear Combination and Vector Spaces

# %% [markdown]
# Scientific programming will be used to visualize linear combinations

# %% [markdown]
# ### Objectives
# At the end of this activity you will be able to:
# 1. Be familiar with representing linear combinations in the 2-dimensional plane.
# 2. Visualize spans using vector fields in Python.
# 3. Perform vector fields operations using scientific programming.

# %% [markdown]
# ## Discussion

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Linear Combination

# %% [markdown]
# It is said that a linear combination is the combination of linear scaling and addition of a vector its bases/components

# %% [markdown]
# We will try to visualize the vectors and their linear combinations by plotting a sample of real number values for the scalars for the vectors. Let's first try the vectors below:

# %% [markdown]
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX =  np.array([2,5])
vectY =  np.array([7,9])
vectX
# Out:
# array([2, 5])

# %% [markdown]
# #### Span of single vectors

# %% [markdown]
# As discussed in the lecture, the span of individual vectors can be represented by a line span. Let's take vector $X$ as an example.

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.125)

plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$Y = c\cdot \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
c = np.arange(-15,15,0.5)

plt.scatter(c*vectY[0],c*vectY[1])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### Span of a linear combination of vectors

# %% [markdown]
# So what if we are to plot the span of a linear combination of vectors? We can visualize as a plane on the 2-dimensional coordinate system. Let's take the span of the linear combination below:

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
vectP = np.array([2,1])
vectQ = np.array([4,3])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectP + vectQ
spanRx = c1*vectP[0] + c2*vectQ[0]
spanRy = c1*vectP[1] + c2*vectQ[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# Take note that if vectors are seen to be as a 2-dimensional span we can say it has a Rank of 2 or $\mathbb{R}^2$. But if the span of the linear combination of vectors are seen to be like a line, they are said to be <b> linearly dependent </b> and they have a rank of 1 or $\mathbb{R}^1$.

# %% [markdown]
# ##Methodology
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# 1. Import python libraries
# 2. Input vectors
# 3. np.arange() is used in order to set desired intervals and spaces for the values
# 3. np.meshgrid() is used to create a rectangular grid based on the arrays
# 4. spanRx() and spanRy() are used to determine the horizontal and vertical boundaries of the array
# 5. plt.scatter() is used to plot one dot for each observation
# 6. plt.axhline() and axvline are used to add horizontal and vertical lines across the axis.
# 7. Display the output graph by using the plt.show() and plt.grid() to reveal the gridlines

# %% [markdown]
# ##Result

# %% [markdown]
# :$$Y = e \cdot (2\hat{x}- 6\hat{y})
# \\= s \cdot (-3 \hat{x}+ \hat{y})$$

# %% [markdown]
# $$Y = \begin{Bmatrix} e \cdot\begin{bmatrix} 2\\-6 \\\end{bmatrix},
# s \cdot \begin{bmatrix} -3\\1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([2,-6])
vectB = np.array([-3,1])

R = np.arange(-15,15,0.5)

c1, c2 = np.meshgrid(R,R)

vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# :$$W = i \cdot (8\hat{x}- 5\hat{y} + 3\hat{z})
# \\= n \cdot (-1 \hat{x}+ 4\hat{y})+ 3\hat{z}$$

# %% [markdown]
# $$W = \begin{Bmatrix} i \cdot\begin{bmatrix} 8\\-5 \\3 \\\end{bmatrix},
# n \cdot \begin{bmatrix} -1\\4 \\3 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([8,-5,3])
vectB = np.array([-1,4,3])

R = np.arange(-10,10,0.5)

c1, c2 = np.meshgrid(R,R)

vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# :$$G = o \cdot (2\hat{x}- 1\hat{y})
# \\= l \cdot (-4 \hat{x}+ 3\hat{y})
# \\= d \cdot (6\hat{x}+ 5\hat{y})$$

# %% [markdown]
# $$G = \begin{Bmatrix} o \cdot\begin{bmatrix} 2\\-1 \\\end{bmatrix},
# l \cdot \begin{bmatrix} -4\\3\\\end{bmatrix}, d \cdot \begin{bmatrix} 6\\5\\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([2,-1])
vectB = np.array([-4,3])
vectC = np.array([6,5])

R = np.arange(-5,5,0.8)

c1, c2, c3 = np.meshgrid(R,R,R)

vectR = vectA + vectB + vectC
spanRx = c1*vectA[0] + c2*vectB[0] + c3*vectC[0]
spanRy = c1*vectA[1] + c2*vectB[1] + c3*vectC[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this experiment, the plotting of linear combinations were demonstrated. By exploring how each function works, I was able to see and observe how linear combinations are programmed to be represented as a graph. I was able to explore various shapes and observe how the number of vectors affect the graph.
#
# Linear combinations can be used to observe the relationship of variables in various engineering applications. It is an effective tool in estimating and observing the behavior of various variables.
